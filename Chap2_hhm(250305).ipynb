# %%
import numpy as np
import pandas as pd
file_path = "./ref/titanic.csv"
titanic = pd.read_csv(file_path)
print(titanic.head(5))
titanic_df=pd.DataFrame(titanic)
titanic_df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(titanic_df[['Age', 'Name']][titanic_df['Age'] >= 60].head(3))
# Out:
#      Age                            Name
# 33  66.0           Wheadon, Mr. Edward H
# 54  65.0  Ostby, Mr. Engelhart Cornelius
# 96  71.0       Goldschmidt, Mr. George B

# %%
print(titanic_df[['Name','Pclass','Age']][titanic_df['Survived'] == 1].head(5))
# Out:
#                                                 Name  Pclass   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0
# 2                             Heikkinen, Miss. Laina       3  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)       2  14.0

# %%
print(titanic_df[['Name','Pclass','Age']][titanic_df['Survived'] == 1].head(5))
# Out:
#                                                 Name  Pclass   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0
# 2                             Heikkinen, Miss. Laina       3  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)       2  14.0

# %%
count = titanic_df[(titanic_df['Age'] >= 60) & 
                   (titanic_df['Pclass'] == 1) & 
                   (titanic_df['Sex'] == 'female')].shape[0]
print(count)
# Out:
# 3

# %%
count1 = titanic_df[(titanic_df['Survived'] == 1) &
                   (titanic_df['Pclass'] == 1) & 
                   (titanic_df['Sex'] == 'female')].shape[0]
count2 = titanic_df[(titanic_df['Survived'] == 1) &
                   (titanic_df['Pclass'] == 2) & 
                   (titanic_df['Sex'] == 'female')].shape[0]
count3 = titanic_df[(titanic_df['Survived'] == 1) &
                   (titanic_df['Pclass'] == 3) & 
                   (titanic_df['Sex'] == 'female')].shape[0]
print(f'1등급 여성 생존자 {count1}\n2등급 여성 생존자 {count2}\n3등급 여성 생존자 {count3}')
# Out:
# 1등급 여성 생존자 91
# 2등급 여성 생존자 70
# 3등급 여성 생존자 72

# %%
titanic_data = titanic.copy()
titanic_data = titanic.groupby('Pclass').count()
titanic_data
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
import numpy as np
import pandas as pd
file_path = "./ref/iris.csv"
iris = pd.read_csv(file_path)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].unique()
iris['class'] = iris['species']

# %%
iris['species'].nunique()
# Out:
# 3

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
iris['sepal_length'].iloc[0:10]
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# 5    5.4
# 6    4.6
# 7    5.0
# 8    4.4
# 9    4.9
# Name: sepal_length, dtype: float64

# %%
Series = iris['sepal_length'] / iris['petal_length']
Series
# Out:
# 0      3.642857
# 1      3.500000
# 2      3.615385
# 3      3.066667
# 4      3.571429
#          ...
# 145    1.288462
# 146    1.260000
# 147    1.250000
# 148    1.148148
# 149    1.156863
# Length: 150, dtype: float64

# %%
iris_data = iris[iris['sepal_length']>5]
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#          class
# 0       setosa
# 5       setosa
# 10      setosa
# 14      setosa
# 15      setosa
# ..         ...
# 145  virginica
# ...

# %%
iris_data = iris[(iris['sepal_length']>5) &
                 (iris['petal_length']<1.5)]
iris_data
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species   class
# 0            5.1          3.5           1.4          0.2  setosa  setosa
# 14           5.8          4.0           1.2          0.2  setosa  setosa
# 16           5.4          3.9           1.3          0.4  setosa  setosa
# 17           5.1          3.5           1.4          0.3  setosa  setosa
# 28           5.2          3.4           1.4          0.2  setosa  setosa
# 33           5.5          4.2           1.4          0.2  setosa  setosa
# 36           5.5          3.5           1.3          0.2  setosa  setosa

# %%
iris_data = iris['petal_width'][(iris['sepal_length'] > 5) & 
                   (iris['petal_length'] < 1.5)]
iris_data
# Out:
# 0     0.2
# 14    0.2
# 16    0.4
# 17    0.3
# 28    0.2
# 33    0.2
# 36    0.2
# Name: petal_width, dtype: float64

# %%
iris_data = iris.groupby('class').sum()
iris_data
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  \
# class
# setosa             250.3        171.4          73.1         12.3
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3
#
#                                                       species
# class
# setosa      setosasetosasetosasetosasetosasetosasetosaseto...
# versicolor  versicolorversicolorversicolorversicolorversic...
# virginica   virginicavirginicavirginicavirginicavirginicav...

# %%
numeric_data = iris.select_dtypes(include=['number'])
iris_data = numeric_data.groupby(iris['species']).max() - numeric_data.groupby(iris['species']).min()
iris_data
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  \
# species
# setosa               1.5          2.1           0.9          0.5
# versicolor           2.1          1.4           2.1          0.8
# virginica            3.0          1.6           2.4          1.1
#
#             class_numeric
# species
# setosa                  0
# versicolor              0
# virginica               0
